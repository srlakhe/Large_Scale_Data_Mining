# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ma_neutral_norm_hr = np.loadtxt("data/sentiment/tb/ma_neutral_norm_hr.txt", delimiter=",")
ma_positive_norm_hr = np.loadtxt("data/sentiment/tb/ma_positive_norm_hr.txt", delimiter=",")
ma_negative_norm_hr = np.loadtxt("data/sentiment/tb/ma_negative_norm_hr.txt", delimiter=",")

wa_neutral_norm_hr = np.loadtxt("data/sentiment/tb/wa_neutral_norm_hr.txt", delimiter=",")
wa_positive_norm_hr = np.loadtxt("data/sentiment/tb/wa_positive_norm_hr.txt", delimiter=",")
wa_negative_norm_hr = np.loadtxt("data/sentiment/tb/wa_negative_norm_hr.txt", delimiter=",")

# %%
ind = np.arange(24) 
width = 0.5
#p1 = plt.bar(ind, wa_neutral_norm_hr, width, color='blue')
#p2 = plt.bar(ind, wa_positive_norm_hr, width, bottom=wa_neutral_norm_hr, color='green')
p2 = plt.bar(ind, wa_positive_norm_hr, width, color='green')
p3 = plt.bar(ind, wa_negative_norm_hr, width, bottom=wa_positive_norm_hr, color='red')
#p3 = plt.bar(ind, wa_negative_norm_hr, width, bottom=sumzip(wa_positive_norm_hr, wa_neutral_norm_hr), color='red')

plt.ylabel('Scores')
plt.title('Sentiments for WA')
#plt.xticks(ind, date_key)
#plt.yticks(np.arange(0, 81, 10))
plt.legend((p2[0], p3[0]), ('Positive', 'Negative'))

plt.show()

# %%
ind = np.arange(24) 
width = 0.5
#p1 = plt.bar(ind, wa_neutral_norm_hr, width, color='blue')
#p2 = plt.bar(ind, wa_positive_norm_hr, width, bottom=wa_neutral_norm_hr, color='green')
p2 = plt.bar(ind, ma_positive_norm_hr, width, color='green')
p3 = plt.bar(ind, ma_negative_norm_hr, width, bottom=ma_positive_norm_hr, color='red')
#p3 = plt.bar(ind, wa_negative_norm_hr, width, bottom=sumzip(wa_positive_norm_hr, wa_neutral_norm_hr), color='red')

plt.ylabel('Scores')
plt.title('Sentiments for MA')
#plt.xticks(ind, date_key)
#plt.yticks(np.arange(0, 81, 10))
plt.legend((p2[0], p3[0]), ('Positive', 'Negative'))

plt.show()

# %%
ma_neutral_norm = np.loadtxt("data/sentiment/tb/ma_neutral_norm.txt", delimiter=",")
ma_positive_norm = np.loadtxt("data/sentiment/tb/ma_positive_norm.txt", delimiter=",")
ma_negative_norm = np.loadtxt("data/sentiment/tb/ma_negative_norm.txt", delimiter=",")

wa_neutral_norm = np.loadtxt("data/sentiment/tb/wa_neutral_norm.txt", delimiter=",")
wa_positive_norm = np.loadtxt("data/sentiment/tb/wa_positive_norm.txt", delimiter=",")
wa_negative_norm = np.loadtxt("data/sentiment/tb/wa_negative_norm.txt", delimiter=",")

# %%
ind = np.arange(24) 
width = 0.5
#p1 = plt.bar(ind, wa_neutral_norm_hr, width, color='blue')
#p2 = plt.bar(ind, wa_positive_norm_hr, width, bottom=wa_neutral_norm_hr, color='green')
p2 = plt.bar(ind, wa_positive_norm, width, color='green')
p3 = plt.bar(ind, wa_negative_norm, width, bottom=wa_positive_norm, color='red')
#p3 = plt.bar(ind, wa_negative_norm_hr, width, bottom=sumzip(wa_positive_norm_hr, wa_neutral_norm_hr), color='red')

plt.ylabel('Scores')
plt.title('Sentiments for WA')
#plt.xticks(ind, date_key)
#plt.yticks(np.arange(0, 81, 10))
plt.legend((p2[0], p3[0]), ('Positive', 'Negative'))

plt.show()

# %%
ind = np.arange(25) 
width = 0.5
#p1 = plt.bar(ind, wa_neutral_norm_hr, width, color='blue')
#p2 = plt.bar(ind, wa_positive_norm_hr, width, bottom=wa_neutral_norm_hr, color='green')
p2 = plt.bar(ind, ma_positive_norm, width, color='green')
p3 = plt.bar(ind, ma_negative_norm, width, bottom=ma_positive_norm, color='red')
#p3 = plt.bar(ind, wa_negative_norm_hr, width, bottom=sumzip(wa_positive_norm_hr, wa_neutral_norm_hr), color='red')

plt.ylabel('Scores')
plt.title('Sentiments for MA')
#plt.xticks(ind, date_key)
#plt.yticks(np.arange(0, 81, 10))
plt.legend((p2[0], p3[0]), ('Positive', 'Negative'))

plt.show()

# %%
ma_neutral = np.loadtxt("data/sentiment/tb/ma_neutral.txt", delimiter=",")
ma_positive = np.loadtxt("data/sentiment/tb/ma_positive.txt", delimiter=",")
ma_negative = np.loadtxt("data/sentiment/tb/ma_negative.txt", delimiter=",")

wa_neutral = np.loadtxt("data/sentiment/tb/wa_neutral.txt", delimiter=",")
wa_positive = np.loadtxt("data/sentiment/tb/wa_positive.txt", delimiter=",")
wa_negative = np.loadtxt("data/sentiment/tb/wa_negative.txt", delimiter=",")

# %%
x_values = range(0,25)
plt.plot(x_values, ma_positive, x_values, ma_negative)
plt.ylabel('No of Tweets')
plt.xlabel('Days data collected from Jan-14th to Feb-7th')
plt.title('Sentiments for MA over different days')
plt.show()

# %%
x_values = range(0,24)
plt.plot(x_values, wa_positive, x_values, wa_negative)
plt.ylabel('No of Tweets')
plt.xlabel('Days data collected from Jan-14th to Feb-7th')
plt.title('Sentiments for WA over different days')
plt.show()

# %%
ma_neutral_hr = np.loadtxt("data/sentiment/tb/ma_neutral_hr.txt", delimiter=",")
ma_positive_hr = np.loadtxt("data/sentiment/tb/ma_positive_hr.txt", delimiter=",")
ma_negative_hr = np.loadtxt("data/sentiment/tb/ma_negative_hr.txt", delimiter=",")

wa_neutral_hr = np.loadtxt("data/sentiment/tb/wa_neutral_hr.txt", delimiter=",")
wa_positive_hr = np.loadtxt("data/sentiment/tb/wa_positive_hr.txt", delimiter=",")
wa_negative_hr = np.loadtxt("data/sentiment/tb/wa_negative_hr.txt", delimiter=",")

# %%
x_values = range(0,24)
plt.plot(x_values, ma_positive_hr, x_values, ma_negative_hr)
plt.ylabel('No of Tweets')
plt.xlabel('Hour of the day (0-23)')
plt.title('Sentiments for MA on Game day')
plt.show()
plt.show()

# %%
x_values = range(0,24)
plt.plot(x_values, wa_positive_hr, x_values, wa_negative_hr)
plt.ylabel('No of Tweets')
plt.xlabel('Hour of the day (0-23)')
plt.title('Sentiments for WA on Game day')
plt.show()

# %%
x_values = range(0,24)
plt.plot(x_values, wa_positive_hr, x_values, wa_negative_hr)
plt.ylabel('No of Tweets')
plt.xlabel('Hour of the day (0-23)')
plt.title('Sentiments for tweets from WA on Game day')
plt.legend(('Positive', 'Negative'))
plt.show()

# %%
x_values = range(0,24)
plt.plot(x_values, ma_positive_hr, x_values, ma_negative_hr)
plt.ylabel('No of Tweets')
plt.xlabel('Hour of the day (0-23)')
plt.title('Sentiments for tweets from MA on Game day')
plt.legend(('Positive', 'Negative'))
plt.show()

# %%
x_values = range(0,24)
plt.plot(x_values, wa_positive, x_values, wa_negative)
plt.ylabel('No of Tweets')
plt.xlabel('Days data collected from Jan-14th to Feb-7th')
plt.title('Sentiments for tweets from WA over different days')
plt.legend(('Positive', 'Negative'))
plt.show()

# %%
x_values = range(0,25)
plt.plot(x_values, ma_positive, x_values, ma_negative)
plt.ylabel('No of Tweets')
plt.xlabel('Days data collected from Jan-14th to Feb-7th')
plt.title('Sentiments for tweets from MA over different days')
plt.legend(('Positive', 'Negative'))
plt.show()
